# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
AirData = pd.read_excel(file.read("AirQuality.xlsx"), engine='openpyxl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11696\3865449043.py in <module>
# ----> 1 AirData = pd.read_excel(file.read("AirQuality.xlsx"), engine='openpyxl')
#
# NameError: name 'file' is not defined

# %%
AirData
# Out:
#     Patient Id  Age  Gender  Air Pollution  Dust Allergy  \
# 0           P1   33       1              2             5
# 1          P10   17       1              3             5
# 2         P100   35       1              4             6
# 3        P1000   37       1              7             7
# 4         P101   46       1              6             7
# ..         ...  ...     ...            ...           ...
# 995       P995   44       1              6             7
# 996       P996   37       2              6             7
# 997       P997   25       2              4             6
# 998       P998   18       2              6             7
# 999       P999   47       1              6             6
#
#      chronic Lung Disease  Shortness of Breath  Wheezing  Frequent Cold  \
# 0                       2                    2         2              2
# 1                       2                    7         8              1
# ...

# %%
AirData.info
# Out:
# <bound method DataFrame.info of     Patient Id  Age  Gender  Air Pollution  Dust Allergy  \
# 0           P1   33       1              2             5
# 1          P10   17       1              3             5
# 2         P100   35       1              4             6
# 3        P1000   37       1              7             7
# 4         P101   46       1              6             7
# ..         ...  ...     ...            ...           ...
# 995       P995   44       1              6             7
# 996       P996   37       2              6             7
# 997       P997   25       2              4             6
# 998       P998   18       2              6             7
# 999       P999   47       1              6             6
#
#      chronic Lung Disease  Shortness of Breath  Wheezing  Frequent Cold  \
# 0                       2                    2         2              2
# 1                       2                    7         8              1
# ...

# %%
AirData.describe()
# Out:
#                Age       Gender  Air Pollution  Dust Allergy  \
# count  1000.000000  1000.000000      1000.0000   1000.000000
# mean     37.174000     1.402000         3.8400      5.165000
# std      12.005493     0.490547         2.0304      1.980833
# min      14.000000     1.000000         1.0000      1.000000
# 25%      27.750000     1.000000         2.0000      4.000000
# 50%      36.000000     1.000000         3.0000      6.000000
# 75%      45.000000     2.000000         6.0000      7.000000
# max      73.000000     2.000000         8.0000      8.000000
#
#        chronic Lung Disease  Shortness of Breath     Wheezing  Frequent Cold  \
# count           1000.000000          1000.000000  1000.000000    1000.000000
# mean               4.380000             4.240000     3.777000       3.536000
# std                1.848518             2.285087     2.041921       1.832502
# min                1.000000             1.000000     1.000000       1.000000
# ...

# %%
AirDataCorr = AirData.corr()
fig,ax = plt.subplots(figsize = (20,20))
sns.heatmap(AirDataCorr,annot = True)
# Out:
# <AxesSubplot:>

# %%
AirData.hist(bins = 100,figsize = (20,20))
plt.show()

# %%
fig, ax = plt.subplots()
hist = ax.hist(x = AirData["Age"])

# %%
fig, ax = plt.subplots()
plot = sns.countplot(data = AirData, x='chronic Lung Disease', hue='Air Pollution', palette=['violet', 'indigo','blue', 'green','yellow', 'orange' , 'red' , 'white'])

# %%
fig, ax = plt.subplots()
plot = sns.countplot(data = AirData, x='Frequent Cold', hue='Air Pollution', palette=['violet', 'indigo','blue', 'green','yellow', 'orange' , 'red' , 'white'])

# %%
fig, ax = plt.subplots()
hist = ax.hist(x = AirData["chronic Lung Disease"])

# %%
fig, ax = plt.subplots()
plot = sns.countplot(data = AirData, x='chronic Lung Disease', hue='Gender', palette=['orange','green'])

# %%
fig, ax = plt.subplots()
hist = ax.hist(x = AirData["Air Pollution"])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
AirData['chronic Lung Disease']=le.fit_transform(AirData['chronic Lung Disease'])

# %%
le.classes_
# Out:
# array([1, 2, 3, 4, 5, 6, 7], dtype=int64)

# %%
AirData
# Out:
#     Patient Id  Age  Gender  Air Pollution  Dust Allergy  \
# 0           P1   33       1              2             5
# 1          P10   17       1              3             5
# 2         P100   35       1              4             6
# 3        P1000   37       1              7             7
# 4         P101   46       1              6             7
# ..         ...  ...     ...            ...           ...
# 995       P995   44       1              6             7
# 996       P996   37       2              6             7
# 997       P997   25       2              4             6
# 998       P998   18       2              6             7
# 999       P999   47       1              6             6
#
#      chronic Lung Disease  Shortness of Breath  Wheezing  Frequent Cold  \
# 0                       1                    2         2              2
# 1                       1                    7         8              1
# ...

# %% [markdown]
# ML Model

# %% [markdown]
# SVM

# %%
from sklearn.metrics import(accuracy_score,classification_report,confusion_matrix,precision_score,f1_score,recall_score,roc_auc_score,auc)

# %%
importantFeatures = ['Air Pollution','Dust Allergy','Shortness of Breath','Wheezing','Frequent Cold','Dry Cough']
AirDataNew = AirData[importantFeatures]
AirDataNew.head()
# Out:
#    Air Pollution  Dust Allergy  Shortness of Breath  Wheezing  Frequent Cold  \
# 0              2             5                    2         2              2
# 1              3             5                    7         8              1
# 2              4             6                    9         2              6
# 3              7             7                    3         1              6
# 4              6             7                    4         1              4
#
#    Dry Cough
# 0          3
# 1          7
# 2          7
# 3          7
# 4          2

# %%
from sklearn.model_selection import train_test_split
y = AirData[['chronic Lung Disease']]
x_train,x_test,y_train,y_test = train_test_split(AirDataNew,y,test_size = 0.25)

# %%
from sklearn.svm import LinearSVC
SVC = LinearSVC()
SVC.fit(x_train,y_train)
y_pred = SVC.predict(x_test)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
SVCAccuracy = accuracy_score(y_test,y_pred)
print("Accuracy : ",accuracy_score(y_test,y_pred),"\n")
print("Classification Report : \n",classification_report(y_test,y_pred))
print("Confusion Matrix : \n",confusion_matrix(y_test,y_pred),"\n")
print("Precision Score : ",precision_score(y_test,y_pred,average = None),"\n")
print("Recall Score : ",recall_score(y_test,y_pred,average = None),"\n")
print("F1 Score : ",f1_score(y_test,y_pred,average = None),"\n")
# Out:
# Accuracy :  0.72
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.71      0.45      0.56        11
#            1       0.74      0.66      0.70        47
#            2       0.44      0.87      0.59        31
#            3       0.72      0.70      0.71        37
#            4       0.67      0.17      0.27        24
#            5       0.87      0.94      0.90        77
#            6       1.00      0.65      0.79        23
#
#     accuracy                           0.72       250
#    macro avg       0.74      0.63      0.64       250
# weighted avg       0.76      0.72      0.71       250
#
# Confusion Matrix :
#  [[ 5  0  5  0  0  1  0]
#  [ 0 31  9  7  0  0  0]
#  [ 0  0 27  3  0  1  0]
#  [ 1  0 10 26  0  0  0]
#  [ 0  7 10  0  4  3  0]
#  [ 1  4  0  0  0 72  0]
#  [ 0  0  0  0  2  6 15]]
#
# Precision Score :  [0.71428571 0.73809524 0.44262295 0.72222222 0.66666667 0.86746988
#  1.        ]
#
# ...

# %% [markdown]
# Decision Tree ML

# %%
from sklearn.tree import DecisionTreeClassifier
DC = DecisionTreeClassifier()
DC.fit(x_train,y_train)
y_pred = DC.predict(x_test)
print
DCAccuracy = accuracy_score(y_test,y_pred)
print("Accuracy : ",accuracy_score(y_test,y_pred),"\n")
print("Classification Report : \n",classification_report(y_test,y_pred))
print("Confusion Matrix : \n",confusion_matrix(y_test,y_pred),"\n")
print("Precision Score : ",precision_score(y_test,y_pred,average = None),"\n")
print("Recall Score : ",recall_score(y_test,y_pred,average = None),"\n")
print("F1 Score : ",f1_score(y_test,y_pred,average = None),"\n")
# Out:
# Accuracy :  1.0
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00        47
#            2       1.00      1.00      1.00        31
#            3       1.00      1.00      1.00        37
#            4       1.00      1.00      1.00        24
#            5       1.00      1.00      1.00        77
#            6       1.00      1.00      1.00        23
#
#     accuracy                           1.00       250
#    macro avg       1.00      1.00      1.00       250
# weighted avg       1.00      1.00      1.00       250
#
# Confusion Matrix :
#  [[11  0  0  0  0  0  0]
#  [ 0 47  0  0  0  0  0]
#  [ 0  0 31  0  0  0  0]
#  [ 0  0  0 37  0  0  0]
#  [ 0  0  0  0 24  0  0]
#  [ 0  0  0  0  0 77  0]
#  [ 0  0  0  0  0  0 23]]
#
# Precision Score :  [1. 1. 1. 1. 1. 1. 1.]
#
# Recall Score :  [1. 1. 1. 1. 1. 1. 1.]
#
# ...

# %% [markdown]
# Random Forest ML

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier()
RF.fit(x_train,y_train)
y_pred_rf = RF.predict(x_test)

RFAccuracy = accuracy_score(y_test,y_pred_rf)
print("Accuracy : ",accuracy_score(y_test,y_pred_rf),"\n")
print("Classification Report : \n",classification_report(y_test,y_pred_rf))
print("Confusion Matrix : \n",confusion_matrix(y_test,y_pred_rf),"\n")
print("Precision Score : ",precision_score(y_test,y_pred_rf,average = None),"\n")
print("Recall Score : ",recall_score(y_test,y_pred_rf,average = None),"\n")
print("F1 Score : ",f1_score(y_test,y_pred_rf,average = None),"\n")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11696\3877482490.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF.fit(x_train,y_train)
# Accuracy :  1.0
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00        47
#            2       1.00      1.00      1.00        31
#            3       1.00      1.00      1.00        37
#            4       1.00      1.00      1.00        24
#            5       1.00      1.00      1.00        77
#            6       1.00      1.00      1.00        23
#
#     accuracy                           1.00       250
#    macro avg       1.00      1.00      1.00       250
# weighted avg       1.00      1.00      1.00       250
#
# Confusion Matrix :
#  [[11  0  0  0  0  0  0]
#  [ 0 47  0  0  0  0  0]
# ...

# %% [markdown]
# LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
regg = LogisticRegression(random_state = 4)
regg.fit(x_train,y_train)
y_pred_LR = regg.predict(x_test)
print('Accuracy: {}'.format(regg.score(x_test, y_test)))
print(classification_report(y_test, y_pred_LR))
# Out:
# Accuracy: 0.772
#               precision    recall  f1-score   support
#
#            0       0.50      0.64      0.56        11
#            1       0.79      0.66      0.72        47
#            2       0.58      0.90      0.71        31
#            3       0.68      0.70      0.69        37
#            4       0.54      0.29      0.38        24
#            5       0.95      0.94      0.94        77
#            6       1.00      0.96      0.98        23
#
#     accuracy                           0.77       250
#    macro avg       0.72      0.73      0.71       250
# weighted avg       0.78      0.77      0.77       250
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# Saving the Trained Model

# %%
import pickle

# %%
filename = "trained_model.sav"
pickle.dump(RF,open(filename,'wb'))
